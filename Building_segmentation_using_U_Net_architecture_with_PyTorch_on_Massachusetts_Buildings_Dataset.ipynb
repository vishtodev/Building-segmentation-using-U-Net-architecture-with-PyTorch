# %%
#=========================================================U-NET FOR BUILDING SEGMENTATION=========================================================

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler

import albumentations as A
from albumentations.pytorch import ToTensorV2


# DEVICE

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using:", DEVICE)

if DEVICE == "cuda":
    print(torch.cuda.get_device_name(0))

#=========================================================PATHS=========================================================

BASE_PATH = "/content/png"

TRAIN_IMG_DIR = os.path.join(BASE_PATH, "train")
TRAIN_MASK_DIR = os.path.join(BASE_PATH, "train_labels")

VAL_IMG_DIR = os.path.join(BASE_PATH, "val")
VAL_MASK_DIR = os.path.join(BASE_PATH, "val_labels")

TEST_IMG_DIR = os.path.join(BASE_PATH, "test")
TEST_MASK_DIR = os.path.join(BASE_PATH, "test_labels")

#=========================================================HYPERPARAMETERS=========================================================

IMAGE_HEIGHT = 512
IMAGE_WIDTH = 512

BATCH_SIZE = 4
LEARNING_RATE = 1e-4
NUM_EPOCHS = 100

NUM_WORKERS = 2
PIN_MEMORY = True

THRESHOLD = 0.5
EARLY_STOPPING_PATIENCE = 15

#=========================================================DATASET=========================================================

class BuildingDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = sorted(os.listdir(image_dir))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        img_name = self.images[index]

        img_path = os.path.join(self.image_dir, img_name)
        mask_path = os.path.join(self.mask_dir, img_name)

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = mask.astype(np.float32) / 255.0

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented["image"]
            mask = augmented["mask"]

        mask = mask.unsqueeze(0)

        return image, mask

#=========================================================AUGMENTATIONS=========================================================

train_transform = A.Compose([
    A.Resize(IMAGE_HEIGHT, IMAGE_WIDTH),

    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),

    A.ShiftScaleRotate(
        shift_limit=0.1,
        scale_limit=0.2,
        rotate_limit=30,
        p=0.5
    ),

    A.RandomBrightnessContrast(p=0.3),
    A.GaussNoise(p=0.2),

    A.Normalize(
        mean=(0.485, 0.456, 0.406),
        std=(0.229, 0.224, 0.225)
    ),

    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(IMAGE_HEIGHT, IMAGE_WIDTH),

    A.Normalize(
        mean=(0.485, 0.456, 0.406),
        std=(0.229, 0.224, 0.225)
    ),

    ToTensorV2()
])

#=========================================================DATA LOADERS=========================================================

train_dataset = BuildingDataset(
    TRAIN_IMG_DIR,
    TRAIN_MASK_DIR,
    transform=train_transform
)

val_dataset = BuildingDataset(
    VAL_IMG_DIR,
    VAL_MASK_DIR,
    transform=val_transform
)

test_dataset = BuildingDataset(
    TEST_IMG_DIR,
    TEST_MASK_DIR,
    transform=val_transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY
)

print("Train samples:", len(train_dataset))
print("Val samples:", len(val_dataset))
print("Test samples:", len(test_dataset))

#=========================================================DOUBLE CONV BLOCK=========================================================

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.2):
        super().__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Dropout2d(dropout),

            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)

#=========================================================U-NET BLOCK=========================================================

class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super().__init__()

        self.pool = nn.MaxPool2d(2, 2)

        # Encoder
        self.down1 = DoubleConv(in_channels, 64)
        self.down2 = DoubleConv(64, 128)
        self.down3 = DoubleConv(128, 256)
        self.down4 = DoubleConv(256, 512)

        # Bottleneck
        self.bottleneck = DoubleConv(512, 1024, dropout=0.3)

        # Decoder
        self.up1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.conv1 = DoubleConv(1024, 512)

        self.up2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.conv2 = DoubleConv(512, 256)

        self.up3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv3 = DoubleConv(256, 128)

        self.up4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv4 = DoubleConv(128, 64)

        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        # Encoder
        d1 = self.down1(x)
        p1 = self.pool(d1)

        d2 = self.down2(p1)
        p2 = self.pool(d2)

        d3 = self.down3(p2)
        p3 = self.pool(d3)

        d4 = self.down4(p3)
        p4 = self.pool(d4)

        # Bottleneck
        bn = self.bottleneck(p4)

        # Decoder
        u1 = self.up1(bn)
        if u1.shape != d4.shape:
            u1 = F.interpolate(u1, size=d4.shape[2:])
        u1 = torch.cat([d4, u1], dim=1)
        u1 = self.conv1(u1)

        u2 = self.up2(u1)
        if u2.shape != d3.shape:
            u2 = F.interpolate(u2, size=d3.shape[2:])
        u2 = torch.cat([d3, u2], dim=1)
        u2 = self.conv2(u2)

        u3 = self.up3(u2)
        if u3.shape != d2.shape:
            u3 = F.interpolate(u3, size=d2.shape[2:])
        u3 = torch.cat([d2, u3], dim=1)
        u3 = self.conv3(u3)

        u4 = self.up4(u3)
        if u4.shape != d1.shape:
            u4 = F.interpolate(u4, size=d1.shape[2:])
        u4 = torch.cat([d1, u4], dim=1)
        u4 = self.conv4(u4)

        return self.final_conv(u4)

#=========================================================MODEL=========================================================

model = UNet().to(DEVICE)

#=========================================================LOSS FUNCTIONS=========================================================

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.8, gamma=2):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.bce = nn.BCEWithLogitsLoss(reduction='none')

    def forward(self, preds, targets):
        bce_loss = self.bce(preds, targets)
        probs = torch.sigmoid(preds)

        pt = torch.where(targets == 1, probs, 1 - probs)
        focal_loss = self.alpha * ((1 - pt) ** self.gamma) * bce_loss

        return focal_loss.mean()

def dice_loss(preds, targets, smooth=1):
    preds = torch.sigmoid(preds)

    preds = preds.view(-1)
    targets = targets.view(-1)

    intersection = (preds * targets).sum()

    dice = (
        (2.0 * intersection + smooth)
        /
        (preds.sum() + targets.sum() + smooth)
    )

    return 1 - dice

focal_loss = FocalLoss()

def combined_loss(preds, targets):
    return focal_loss(preds, targets) + dice_loss(preds, targets)

#=========================================================METRIC=========================================================

def iou_score(preds, masks, threshold=THRESHOLD):
    preds = torch.sigmoid(preds)
    preds = (preds > threshold).float()

    intersection = (preds * masks).sum((1, 2, 3))
    union = preds.sum((1, 2, 3)) + masks.sum((1, 2, 3)) - intersection

    iou = (intersection + 1e-8) / (union + 1e-8)

    return iou.mean()

#=========================================================OPTIMIZER + SCHEDULER=========================================================

optimizer = optim.AdamW(
    model.parameters(),
    lr=LEARNING_RATE,
    weight_decay=1e-4
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=0.5,
    patience=5
)

scaler = GradScaler()

#=========================================================TRAIN FUNCTION=========================================================

def train_fn(loader):
    model.train()
    total_loss = 0

    loop = tqdm(loader)

    for images, masks in loop:
        images = images.to(DEVICE)
        masks = masks.to(DEVICE)

        optimizer.zero_grad()

        with autocast():
            preds = model(images)
            loss = combined_loss(preds, masks)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()
        loop.set_postfix(loss=loss.item())

    return total_loss / len(loader)

# =========================================================
# EVALUATION
# =========================================================
def eval_fn(loader):
    model.eval()

    total_loss = 0
    total_iou = 0

    with torch.no_grad():
        for images, masks in loader:
            images = images.to(DEVICE)
            masks = masks.to(DEVICE)

            preds = model(images)

            loss = combined_loss(preds, masks)
            iou = iou_score(preds, masks)

            total_loss += loss.item()
            total_iou += iou.item()

    return total_loss / len(loader), total_iou / len(loader)


#=========================================================TRAIN LOOP=========================================================

best_iou = 0
patience_counter = 0

for epoch in range(NUM_EPOCHS):
    print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")

    train_loss = train_fn(train_loader)
    val_loss, val_iou = eval_fn(val_loader)

    scheduler.step(val_iou)

    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss:   {val_loss:.4f}")
    print(f"Val IoU:    {val_iou:.4f}")

    if val_iou > best_iou:
        best_iou = val_iou
        patience_counter = 0

        torch.save(model.state_dict(), "best_unet_model.pth")
        print("Best model saved.")

    else:
        patience_counter += 1
        print("Patience:", patience_counter)

    if patience_counter >= EARLY_STOPPING_PATIENCE:
        print("Early stopping triggered.")
        break

#=========================================================LOAD BEST MODE=========================================================
model.load_state_dict(torch.load("best_unet_model.pth"))


#=========================================================TEST=========================================================

test_loss, test_iou = eval_fn(test_loader)

print("\nFINAL TEST RESULTS")
print("Test Loss:", test_loss)
print("Test IoU:", test_iou)

#=========================================================VISUALIZATION=========================================================

def visualize_predictions(loader, num_samples=5):
    model.eval()
    count = 0

    with torch.no_grad():
        for images, masks in loader:
            images = images.to(DEVICE)

            preds = torch.sigmoid(model(images))
            preds = (preds > THRESHOLD).float()

            for i in range(images.shape[0]):
                img = images[i].cpu().permute(1, 2, 0).numpy()
                img = img * np.array([0.229, 0.224, 0.225])
                img = img + np.array([0.485, 0.456, 0.406])
                img = np.clip(img, 0, 1)

                gt = masks[i].squeeze().cpu().numpy()
                pred = preds[i].squeeze().cpu().numpy()

                plt.figure(figsize=(15, 5))

                plt.subplot(1, 3, 1)
                plt.imshow(img)
                plt.title("Input")
                plt.axis("off")

                plt.subplot(1, 3, 2)
                plt.imshow(gt, cmap="gray")
                plt.title("Ground Truth")
                plt.axis("off")

                plt.subplot(1, 3, 3)
                plt.imshow(pred, cmap="gray")
                plt.title("Prediction")
                plt.axis("off")

                plt.show()

                count += 1
                if count >= num_samples:
                    return

visualize_predictions(test_loader)
# Out:
# Using: cuda
# Tesla T4
# Train samples: 137
# Val samples: 4
# Test samples: 10
# /tmp/ipykernel_6568/3380825219.py:362: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Epoch 1/100
#   0%|          | 0/35 [00:00<?, ?it/s]/tmp/ipykernel_6568/3380825219.py:379: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 100%|██████████| 35/35 [00:19<00:00,  1.78it/s, loss=0.868]
# Train Loss: 0.8774
# Val Loss:   0.8254
# Val IoU:    0.2191
# Best model saved.
#
# Epoch 2/100
# 100%|██████████| 35/35 [00:19<00:00,  1.79it/s, loss=0.92]
# Train Loss: 0.8487
# Val Loss:   0.8267
# Val IoU:    0.2631
# Best model saved.
#
# Epoch 3/100
# 100%|██████████| 35/35 [00:19<00:00,  1.84it/s, loss=0.769]
# Train Loss: 0.8330
# Val Loss:   0.7795
# Val IoU:    0.2948
# Best model saved.
#
# Epoch 4/100
# 100%|██████████| 35/35 [00:19<00:00,  1.80it/s, loss=0.733]
# Train Loss: 0.8192
# Val Loss:   0.7529
# Val IoU:    0.3327
# Best model saved.
#
# Epoch 5/100
# 100%|██████████| 35/35 [00:18<00:00,  1.87it/s, loss=0.706]
# Train Loss: 0.8110
# Val Loss:   0.7431
# Val IoU:    0.3336
# Best model saved.
#
# Epoch 6/100
# 100%|██████████| 35/35 [00:18<00:00,  1.91it/s, loss=0.911]
# Train Loss: 0.8114
# Val Loss:   0.7525
# Val IoU:    0.3329
# Patience: 1
#
# Epoch 7/100
# 100%|██████████| 35/35 [00:18<00:00,  1.85it/s, loss=0.677]
# Train Loss: 0.7965
# Val Loss:   0.7227
# Val IoU:    0.3434
# Best model saved.
#
# Epoch 8/100
# 100%|██████████| 35/35 [00:18<00:00,  1.94it/s, loss=0.912]
# Train Loss: 0.7855
# Val Loss:   0.7153
# Val IoU:    0.3666
# Best model saved.
#
# Epoch 9/100
# 100%|██████████| 35/35 [00:19<00:00,  1.82it/s, loss=0.731]
# Train Loss: 0.7813
# Val Loss:   0.7062
# Val IoU:    0.3672
# Best model saved.
#
# Epoch 10/100
# 100%|██████████| 35/35 [00:18<00:00,  1.92it/s, loss=0.691]
# Train Loss: 0.7701
# Val Loss:   0.6969
# Val IoU:    0.3700
# Best model saved.
#
# Epoch 11/100
# 100%|██████████| 35/35 [00:19<00:00,  1.81it/s, loss=0.932]
# Train Loss: 0.7739
# Val Loss:   0.7101
# Val IoU:    0.3533
# Patience: 1
#
# Epoch 12/100
# 100%|██████████| 35/35 [00:18<00:00,  1.93it/s, loss=0.862]
# Train Loss: 0.7582
# Val Loss:   0.6889
# Val IoU:    0.3797
# Best model saved.
#
# Epoch 13/100
# 100%|██████████| 35/35 [00:19<00:00,  1.80it/s, loss=0.86]
# Train Loss: 0.7554
# Val Loss:   0.6621
# Val IoU:    0.3868
# Best model saved.
#
# Epoch 14/100
# 100%|██████████| 35/35 [00:18<00:00,  1.93it/s, loss=0.624]
# Train Loss: 0.7540
# Val Loss:   0.6525
# Val IoU:    0.3919
# Best model saved.
#
# Epoch 15/100
# 100%|██████████| 35/35 [00:19<00:00,  1.84it/s, loss=0.846]
# Train Loss: 0.7509
# Val Loss:   0.6700
# Val IoU:    0.3780
# Patience: 1
#
# Epoch 16/100
# 100%|██████████| 35/35 [00:18<00:00,  1.92it/s, loss=0.756]
# Train Loss: 0.7408
# Val Loss:   0.6621
# Val IoU:    0.3793
# Patience: 2
#
# Epoch 17/100
# 100%|██████████| 35/35 [00:18<00:00,  1.89it/s, loss=0.793]
# Train Loss: 0.7391
# Val Loss:   0.6434
# Val IoU:    0.4028
# Best model saved.
#
# Epoch 18/100
# 100%|██████████| 35/35 [00:18<00:00,  1.91it/s, loss=0.888]
# Train Loss: 0.7395
# Val Loss:   0.6484
# Val IoU:    0.3918
# Patience: 1
#
# Epoch 19/100
# 100%|██████████| 35/35 [00:19<00:00,  1.79it/s, loss=0.743]
# Train Loss: 0.7305
# Val Loss:   0.6327
# Val IoU:    0.4081
# Best model saved.
#
# Epoch 20/100
# 100%|██████████| 35/35 [00:19<00:00,  1.78it/s, loss=0.685]
# Train Loss: 0.7292
# Val Loss:   0.6363
# Val IoU:    0.3946
# Patience: 1
#
# Epoch 21/100
# 100%|██████████| 35/35 [00:19<00:00,  1.76it/s, loss=0.693]
# Train Loss: 0.7116
# Val Loss:   0.6168
# Val IoU:    0.4130
# Best model saved.
#
# Epoch 22/100
# 100%|██████████| 35/35 [00:19<00:00,  1.79it/s, loss=0.6]
# Train Loss: 0.7243
# Val Loss:   0.6174
# Val IoU:    0.4051
# Patience: 1
#
# Epoch 23/100
# 100%|██████████| 35/35 [00:21<00:00,  1.66it/s, loss=0.635]
# Train Loss: 0.7219
# Val Loss:   0.6226
# Val IoU:    0.4051
# Patience: 2
#
# Epoch 24/100
# 100%|██████████| 35/35 [00:19<00:00,  1.81it/s, loss=0.645]
# Train Loss: 0.7198
# Val Loss:   0.6042
# Val IoU:    0.4182
# Best model saved.
#
# Epoch 25/100
# 100%|██████████| 35/35 [00:20<00:00,  1.68it/s, loss=0.61]
# Train Loss: 0.7169
# Val Loss:   0.6202
# Val IoU:    0.4018
# Patience: 1
#
# Epoch 26/100
# 100%|██████████| 35/35 [00:19<00:00,  1.78it/s, loss=0.708]
# Train Loss: 0.7084
# Val Loss:   0.6126
# Val IoU:    0.4097
# Patience: 2
#
# Epoch 27/100
# 100%|██████████| 35/35 [00:21<00:00,  1.65it/s, loss=0.596]
# Train Loss: 0.7163
# Val Loss:   0.6308
# Val IoU:    0.4005
# Patience: 3
#
# Epoch 28/100
# 100%|██████████| 35/35 [00:19<00:00,  1.77it/s, loss=0.644]
# Train Loss: 0.7102
# Val Loss:   0.6032
# Val IoU:    0.4125
# Patience: 4
#
# Epoch 29/100
# 100%|██████████| 35/35 [00:20<00:00,  1.70it/s, loss=0.804]
# Train Loss: 0.7054
# Val Loss:   0.6030
# Val IoU:    0.4157
# Patience: 5
#
# Epoch 30/100
# 100%|██████████| 35/35 [00:19<00:00,  1.82it/s, loss=0.772]
# Train Loss: 0.6940
# Val Loss:   0.5915
# Val IoU:    0.4253
# Best model saved.
#
# Epoch 31/100
# 100%|██████████| 35/35 [00:20<00:00,  1.70it/s, loss=0.782]
# Train Loss: 0.7008
# Val Loss:   0.5944
# Val IoU:    0.4189
# Patience: 1
#
# Epoch 32/100
# 100%|██████████| 35/35 [00:19<00:00,  1.82it/s, loss=0.588]
# Train Loss: 0.6993
# Val Loss:   0.5912
# Val IoU:    0.4219
# Patience: 2
#
# Epoch 33/100
# 100%|██████████| 35/35 [00:19<00:00,  1.81it/s, loss=0.573]
# Train Loss: 0.6928
# Val Loss:   0.5919
# Val IoU:    0.4231
# Patience: 3
#
# Epoch 34/100
# 100%|██████████| 35/35 [00:18<00:00,  1.88it/s, loss=0.618]
# Train Loss: 0.6976
# Val Loss:   0.5908
# Val IoU:    0.4175
# Patience: 4
#
# Epoch 35/100
# 100%|██████████| 35/35 [00:18<00:00,  1.87it/s, loss=0.74]
# Train Loss: 0.6957
# Val Loss:   0.5575
# Val IoU:    0.4508
# Best model saved.
#
# Epoch 36/100
# 100%|██████████| 35/35 [00:18<00:00,  1.90it/s, loss=0.744]
# Train Loss: 0.6850
# Val Loss:   0.5910
# Val IoU:    0.4216
# Patience: 1
#
# Epoch 37/100
# 100%|██████████| 35/35 [00:18<00:00,  1.87it/s, loss=0.774]
# Train Loss: 0.6913
# Val Loss:   0.5641
# Val IoU:    0.4421
# Patience: 2
#
# Epoch 38/100
# 100%|██████████| 35/35 [00:18<00:00,  1.94it/s, loss=0.575]
# Train Loss: 0.6936
# Val Loss:   0.5724
# Val IoU:    0.4320
# Patience: 3
#
# Epoch 39/100
# 100%|██████████| 35/35 [00:19<00:00,  1.84it/s, loss=0.711]
# Train Loss: 0.6810
# Val Loss:   0.5560
# Val IoU:    0.4505
# Patience: 4
#
# Epoch 40/100
# 100%|██████████| 35/35 [00:17<00:00,  1.94it/s, loss=0.561]
# Train Loss: 0.6842
# Val Loss:   0.5619
# Val IoU:    0.4433
# Patience: 5
#
# Epoch 41/100
# 100%|██████████| 35/35 [00:19<00:00,  1.83it/s, loss=0.607]
# Train Loss: 0.6814
# Val Loss:   0.5596
# Val IoU:    0.4474
# Patience: 6
#
# Epoch 42/100
# 100%|██████████| 35/35 [00:18<00:00,  1.94it/s, loss=0.666]
# Train Loss: 0.6817
# Val Loss:   0.5657
# Val IoU:    0.4410
# Patience: 7
#
# Epoch 43/100
# 100%|██████████| 35/35 [00:19<00:00,  1.83it/s, loss=0.582]
# Train Loss: 0.6761
# Val Loss:   0.5590
# Val IoU:    0.4482
# Patience: 8
#
# Epoch 44/100
# 100%|██████████| 35/35 [00:18<00:00,  1.94it/s, loss=0.629]
# Train Loss: 0.6632
# Val Loss:   0.5661
# Val IoU:    0.4416
# Patience: 9
#
# Epoch 45/100
# 100%|██████████| 35/35 [00:18<00:00,  1.88it/s, loss=0.904]
# Train Loss: 0.6782
# Val Loss:   0.5626
# Val IoU:    0.4425
# Patience: 10
#
# Epoch 46/100
# 100%|██████████| 35/35 [00:18<00:00,  1.92it/s, loss=0.575]
# Train Loss: 0.6678
# Val Loss:   0.5489
# Val IoU:    0.4478
# Patience: 11
#
# Epoch 47/100
# 100%|██████████| 35/35 [00:18<00:00,  1.93it/s, loss=0.593]
# Train Loss: 0.6779
# Val Loss:   0.5531
# Val IoU:    0.4500
# Patience: 12
#
# Epoch 48/100
# 100%|██████████| 35/35 [00:17<00:00,  1.97it/s, loss=0.602]
# Train Loss: 0.6683
# Val Loss:   0.5598
# Val IoU:    0.4475
# Patience: 13
#
# Epoch 49/100
# 100%|██████████| 35/35 [00:17<00:00,  1.96it/s, loss=0.585]
# Train Loss: 0.6676
# Val Loss:   0.5502
# Val IoU:    0.4494
# Patience: 14
#
# Epoch 50/100
# 100%|██████████| 35/35 [00:17<00:00,  1.95it/s, loss=0.875]
# Train Loss: 0.6659
# Val Loss:   0.5513
# Val IoU:    0.4509
# Best model saved.
#
# Epoch 51/100
# 100%|██████████| 35/35 [00:17<00:00,  1.95it/s, loss=0.758]
# Train Loss: 0.6566
# Val Loss:   0.5560
# Val IoU:    0.4477
# Patience: 1
#
# Epoch 52/100
# 100%|██████████| 35/35 [00:17<00:00,  1.98it/s, loss=0.772]
# Train Loss: 0.6631
# Val Loss:   0.5565
# Val IoU:    0.4440
# Patience: 2
#
# Epoch 53/100
# 100%|██████████| 35/35 [00:17<00:00,  1.98it/s, loss=0.588]
# Train Loss: 0.6523
# Val Loss:   0.5447
# Val IoU:    0.4575
# Best model saved.
#
# Epoch 54/100
# 100%|██████████| 35/35 [00:18<00:00,  1.89it/s, loss=0.56]
# Train Loss: 0.6637
# Val Loss:   0.5518
# Val IoU:    0.4454
# Patience: 1
#
# Epoch 55/100
# 100%|██████████| 35/35 [00:17<00:00,  1.97it/s, loss=0.619]
# Train Loss: 0.6696
# Val Loss:   0.5540
# Val IoU:    0.4468
# Patience: 2
#
# Epoch 56/100
# 100%|██████████| 35/35 [00:18<00:00,  1.87it/s, loss=0.524]
# Train Loss: 0.6590
# Val Loss:   0.5442
# Val IoU:    0.4524
# Patience: 3
#
# Epoch 57/100
# 100%|██████████| 35/35 [00:17<00:00,  1.98it/s, loss=0.798]
# Train Loss: 0.6585
# Val Loss:   0.5486
# Val IoU:    0.4458
# Patience: 4
#
# Epoch 58/100
# 100%|██████████| 35/35 [00:18<00:00,  1.92it/s, loss=0.696]
# Train Loss: 0.6601
# Val Loss:   0.5429
# Val IoU:    0.4536
# Patience: 5
#
# Epoch 59/100
# 100%|██████████| 35/35 [00:17<00:00,  2.00it/s, loss=0.915]
# Train Loss: 0.6568
# Val Loss:   0.5578
# Val IoU:    0.4403
# Patience: 6
#
# Epoch 60/100
# 100%|██████████| 35/35 [00:17<00:00,  1.99it/s, loss=0.537]
# Train Loss: 0.6440
# Val Loss:   0.5411
# Val IoU:    0.4561
# Patience: 7
#
# Epoch 61/100
# 100%|██████████| 35/35 [00:17<00:00,  1.99it/s, loss=0.572]
# Train Loss: 0.6516
# Val Loss:   0.5435
# Val IoU:    0.4526
# Patience: 8
#
# Epoch 62/100
# 100%|██████████| 35/35 [00:17<00:00,  2.00it/s, loss=0.864]
# Train Loss: 0.6567
# Val Loss:   0.5519
# Val IoU:    0.4446
# Patience: 9
#
# Epoch 63/100
# 100%|██████████| 35/35 [00:18<00:00,  1.91it/s, loss=0.592]
# Train Loss: 0.6483
# Val Loss:   0.5435
# Val IoU:    0.4533
# Patience: 10
#
# Epoch 64/100
# 100%|██████████| 35/35 [00:17<00:00,  1.99it/s, loss=0.864]
# Train Loss: 0.6513
# Val Loss:   0.5467
# Val IoU:    0.4542
# Patience: 11
#
# Epoch 65/100
# 100%|██████████| 35/35 [00:18<00:00,  1.91it/s, loss=0.551]
# Train Loss: 0.6462
# Val Loss:   0.5424
# Val IoU:    0.4527
# Patience: 12
#
# Epoch 66/100
# 100%|██████████| 35/35 [00:17<00:00,  2.02it/s, loss=0.709]
# Train Loss: 0.6602
# Val Loss:   0.5410
# Val IoU:    0.4572
# Patience: 13
#
# Epoch 67/100
# 100%|██████████| 35/35 [00:18<00:00,  1.93it/s, loss=0.5]
# Train Loss: 0.6592
# Val Loss:   0.5414
# Val IoU:    0.4527
# Patience: 14
#
# Epoch 68/100
# 100%|██████████| 35/35 [00:17<00:00,  1.97it/s, loss=0.621]
# Train Loss: 0.6519
# Val Loss:   0.5361
# Val IoU:    0.4619
# Best model saved.
#
# Epoch 69/100
# 100%|██████████| 35/35 [00:18<00:00,  1.92it/s, loss=0.557]
# Train Loss: 0.6463
# Val Loss:   0.5374
# Val IoU:    0.4597
# Patience: 1
#
# Epoch 70/100
# 100%|██████████| 35/35 [00:17<00:00,  1.99it/s, loss=0.644]
# Train Loss: 0.6502
# Val Loss:   0.5400
# Val IoU:    0.4573
# Patience: 2
#
# Epoch 71/100
# 100%|██████████| 35/35 [00:17<00:00,  2.03it/s, loss=0.602]
# Train Loss: 0.6585
# Val Loss:   0.5455
# Val IoU:    0.4514
# Patience: 3
#
# Epoch 72/100
# 100%|██████████| 35/35 [00:17<00:00,  1.98it/s, loss=0.81]
# Train Loss: 0.6640
# Val Loss:   0.5488
# Val IoU:    0.4518
# Patience: 4
#
# Epoch 73/100
# 100%|██████████| 35/35 [00:17<00:00,  1.97it/s, loss=0.552]
# Train Loss: 0.6407
# Val Loss:   0.5371
# Val IoU:    0.4589
# Patience: 5
#
# Epoch 74/100
# 100%|██████████| 35/35 [00:18<00:00,  1.90it/s, loss=0.578]
# Train Loss: 0.6500
# Val Loss:   0.5380
# Val IoU:    0.4595
# Patience: 6
#
# Epoch 75/100
# 100%|██████████| 35/35 [00:17<00:00,  2.00it/s, loss=0.662]
# Train Loss: 0.6506
# Val Loss:   0.5391
# Val IoU:    0.4568
# Patience: 7
#
# Epoch 76/100
# 100%|██████████| 35/35 [00:18<00:00,  1.92it/s, loss=0.819]
# Train Loss: 0.6623
# Val Loss:   0.5383
# Val IoU:    0.4582
# Patience: 8
#
# Epoch 77/100
# 100%|██████████| 35/35 [00:17<00:00,  1.96it/s, loss=0.719]
# Train Loss: 0.6544
# Val Loss:   0.5409
# Val IoU:    0.4558
# Patience: 9
#
# Epoch 78/100
# 100%|██████████| 35/35 [00:18<00:00,  1.89it/s, loss=0.685]
# Train Loss: 0.6499
# Val Loss:   0.5377
# Val IoU:    0.4580
# Patience: 10
#
# Epoch 79/100
# 100%|██████████| 35/35 [00:17<00:00,  2.00it/s, loss=0.623]
# Train Loss: 0.6378
# Val Loss:   0.5389
# Val IoU:    0.4585
# Patience: 11
#
# Epoch 80/100
# 100%|██████████| 35/35 [00:17<00:00,  2.01it/s, loss=0.652]
# Train Loss: 0.6462
# Val Loss:   0.5394
# Val IoU:    0.4562
# Patience: 12
#
# Epoch 81/100
# 100%|██████████| 35/35 [00:17<00:00,  2.00it/s, loss=0.618]
# Train Loss: 0.6419
# Val Loss:   0.5393
# Val IoU:    0.4566
# Patience: 13
#
# Epoch 82/100
# 100%|██████████| 35/35 [00:17<00:00,  1.99it/s, loss=0.712]
# Train Loss: 0.6493
# Val Loss:   0.5378
# Val IoU:    0.4584
# Patience: 14
#
# Epoch 83/100
# 100%|██████████| 35/35 [00:17<00:00,  1.95it/s, loss=0.563]
# Train Loss: 0.6551
# Val Loss:   0.5396
# Val IoU:    0.4569
# Patience: 15
# Early stopping triggered.
#
# FINAL TEST RESULTS
# Test Loss: 0.5191223621368408
# Test IoU: 0.5020505587259928
